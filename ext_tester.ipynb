# %%
import pandas as pd
from utils.ScoreGenerator import ScoreGenerator

# %%
fb = pd.read_csv('F:/capstone_listenfirst/view_brand_rollup_facebook_1k-10k.tsv', delimiter='\t')

# %%
test = pd.read_csv('utils/esther_clusters__1_.csv')

# %%
test = test[test['replace']=='Fury'].loc[:, ['brand_ods_id', 'top_genre', 'rating', 'source', 'franchise', 'inflated_budget']]

# %%
sg = ScoreGenerator(test, fb)

# %%
sg.cluster()

# %%
sg.get_scores()
# Out:
# D:\git\lf_capstone\utils\ScoreGenerator.py:178: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# D:\git\lf_capstone\utils\ScoreGenerator.py:183: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
sg.facebook
# Out:
#        movie_id    data_for  likes_c     likes  talking_about_c  \
# 14572     10617  2014-04-22      0.0       0.0              0.0
# 14573     10617  2014-04-23      0.0       0.0              0.0
# 14574     10617  2014-04-24      0.0       0.0              0.0
# 14575     10617  2014-04-25      0.0       0.0              0.0
# 14576     10617  2014-04-26      0.0       0.0              0.0
# ...         ...         ...      ...       ...              ...
# 13408    129573  2020-04-06      4.0  143766.0              2.0
# 13409    129573  2020-04-07     -3.0  143763.0             14.0
# 13410    129573  2020-04-08     -6.0  143757.0             10.0
# 13411    129573  2020-04-09     -3.0  143754.0              0.0
# 13412    129573  2020-04-10      0.0  143754.0              0.0
#
#        talking_about  engagement_rate_c  engagement_rate  total_post_c  \
# 14572            0.0               0.00             0.00             1
# ...
