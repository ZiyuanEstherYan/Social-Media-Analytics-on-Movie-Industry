# %% [markdown]
# # Clustering: Movie Attributes

# %% [markdown]
# ### Steps
# #### 1. z-scale inflated budget
# #### 2. Select 'replace', 'top_genre', 'rating', 'source', 'franchise', 'inflated_budget'
# #### 3. Factor analysis for mixed data to reduce dimension. n_components = 2.
# #### 4. Hierarchical Clustering. K = 9.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from sklearn.preprocessing import StandardScaler
from light_famd import FAMD
import prince
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import silhouette_score
import pickle

# %%
import os
os.getcwd()
# Out:
# '/srv/jupyterhub/capstone_data/listenfirst/clustering'

# %%
brand_extras = pd.read_csv('../data_concat/brands_with_extras_kmodes.csv')

# %%
brand_extras.isna().sum()
# Out:
# brand_ods_id                         0
# replace                              0
# released_on                          0
# ticker_symbol                      197
# genres                               0
# data_profile_dcs_uid                 0
# data_profile_channel_type            0
# data_profile_source_type             0
# data_affiliation_active_flag         0
# data_affiliation_start_date_key      0
# data_affiliation_end_date_key        0
# genre_list                           0
# top_genre                            0
# released_year                        0
# year_bin                             0
# budget                               0
# production_company                   0
# rating                               0
# source                               0
# franchise                            0
# DomesticGross                        0
# genre_grouped                        0
# inflated_budget                      0
# budget_cat                           0
# inflated_boxoffice                   0
# year_q_bin                           0
# rank                                 0
# production_company_bin               0
# dtype: int64

# %% [markdown]
# ## Filter out old and duplicated movies

# %%
brand_extras = brand_extras[brand_extras['released_year']>=2010].drop_duplicates('replace')

# %%
brand_extras.T
# Out:
#                                                               0    \
# brand_ods_id                                                41301
# replace                                         Blade Runner 2049
# released_on                                            2017-10-06
# ticker_symbol                                                   T
# genres                                                     Sci Fi
# data_profile_dcs_uid             45b03b4ab3e6e5781426f83613af0807
# data_profile_channel_type                               instagram
# data_profile_source_type                                     page
# data_affiliation_active_flag                                    t
# data_affiliation_start_date_key                               101
# data_affiliation_end_date_key                                7769
# genre_list                                             ['Sci Fi']
# top_genre                                                  Sci Fi
# released_year                                                2017
# year_bin                                                        7
# budget                                                   1.85e+08
# production_company                                   Warner Bros.
# rating                                                          R
# source                                                     Remake
# franchise                                                     Yes
# DomesticGross                                            92054159
# genre_grouped                                             Fantasy
# inflated_budget                                       1.92953e+08
# budget_cat                                             HighBudget
# inflated_boxoffice                                    9.60116e+07
# year_q_bin                                                      3
# rank                                                            1
# production_company_bin                                       Top5
#
#                                                               1    \
# brand_ods_id                                                25859
# replace                                                  Geostorm
# released_on                                            2017-10-20
# ticker_symbol                                                   T
# genres                                             Action, Sci Fi
# data_profile_dcs_uid             ea5eb96fa2d53c68a7fec4a76636c6ff
# data_profile_channel_type                                 twitter
# data_profile_source_type                              search_term
# data_affiliation_active_flag                                    t
# data_affiliation_start_date_key                               101
# data_affiliation_end_date_key                                7769
# genre_list                                   ['Action', 'Sci Fi']
# top_genre                                                  Action
# released_year                                                2017
# year_bin                                                        7
# budget                                                      1e+08
# production_company                                   Warner Bros.
# rating                                                      PG-13
# source                                                   Original
# franchise                                                      No
# DomesticGross                                            33700160
# genre_grouped                                              Action
# inflated_budget                                       1.04299e+08
# budget_cat                                             HighBudget
# inflated_boxoffice                                    3.51489e+07
# year_q_bin                                                      3
# rank                                                            1
# production_company_bin                                       Top5
#
#                                                               2    \
# brand_ods_id                                                44895
# replace                                          Ready Player One
# released_on                                            2018-03-29
# ticker_symbol                                                   T
# genres                                   Sci Fi, Action, Thriller
# data_profile_dcs_uid             31e9bbe160e77e8558e35bb5c5bd7089
# data_profile_channel_type                                facebook
# data_profile_source_type                              search_term
# data_affiliation_active_flag                                    t
# data_affiliation_start_date_key                               101
# data_affiliation_end_date_key                                7769
# genre_list                       ['Sci Fi', 'Action', 'Thriller']
# top_genre                                                  Sci Fi
# released_year                                                2018
# year_bin                                                        8
# budget                                                    1.5e+08
# production_company                                   Warner Bros.
# rating                                                      PG-13
# source                                               Not Original
# franchise                                                      No
# DomesticGross                                           137690172
# genre_grouped                                             Fantasy
# inflated_budget                                       1.52718e+08
# budget_cat                                             HighBudget
# inflated_boxoffice                                    1.40185e+08
# year_q_bin                                                      3
# rank                                                            1
# production_company_bin                                       Top5
#
#                                                               3    \
# brand_ods_id                                                10617
# replace                                                      Fury
# released_on                                            2014-10-17
# ticker_symbol                                                 NaN
# genres                                         Action, Drama, War
# data_profile_dcs_uid             6c7dc49a1cece02cc80d0826e6424df2
# data_profile_channel_type                                facebook
# data_profile_source_type                              search_term
# data_affiliation_active_flag                                    t
# data_affiliation_start_date_key                               101
# data_affiliation_end_date_key                                7769
# genre_list                             ['Action', 'Drama', 'War']
# top_genre                                                  Action
# released_year                                                2014
# year_bin                                                        4
# budget                                                      8e+07
# production_company                                  Sony Pictures
# rating                                                          R
# source                                                   Original
# franchise                                                      No
# DomesticGross                                            85817906
# genre_grouped                                              Action
# inflated_budget                                        8.6394e+07
# budget_cat                                             HighBudget
# inflated_boxoffice                                    9.26769e+07
# year_q_bin                                                      1
# rank                                                          193
# production_company_bin                                    Top100+
#
#                                                               4    \
# brand_ods_id                                                10607
# replace                                              Nightcrawler
# released_on                                            2014-10-31
# ticker_symbol                                                 NaN
# genres                                     Crime, Thriller, Drama
# data_profile_dcs_uid             aaec8ee14f2e372b8e35a72ee9613ca1
# data_profile_channel_type                                 twitter
# data_profile_source_type                              search_term
# data_affiliation_active_flag                                    t
# data_affiliation_start_date_key                               101
# data_affiliation_end_date_key                                7769
# genre_list                         ['Crime', 'Thriller', 'Drama']
# top_genre                                                   Crime
# released_year                                                2014
# year_bin                                                        4
# budget                                                    8.5e+06
# production_company                                Open Road Films
# rating                                                          R
# source                                                   Original
# franchise                                                      No
# DomesticGross                                            32381218
# genre_grouped                                            Thriller
# inflated_budget                                       9.17937e+06
# budget_cat                                           MediumBudget
# inflated_boxoffice                                    3.49693e+07
# year_q_bin                                                      1
# rank                                                          223
# production_company_bin                                    Top100+
#
#                                                               5    \
# brand_ods_id                                                13370
# replace                                              Crimson Peak
# released_on                                            2015-10-16
# ticker_symbol                                               CMCSA
# genres                                                     Horror
# data_profile_dcs_uid             7034ae8af3651572a1622a96f47334b4
# data_profile_channel_type                                 twitter
# data_profile_source_type                              search_term
# data_affiliation_active_flag                                    t
# data_affiliation_start_date_key                               101
# data_affiliation_end_date_key                                7769
# genre_list                                             ['Horror']
# top_genre                                                  Horror
# released_year                                                2015
# year_bin                                                        5
# budget                                                    5.5e+07
# production_company                             Universal Pictures
# rating                                                          R
# source                                                   Original
# franchise                                                      No
# DomesticGross                                            31090320
# genre_grouped                                              Horror
# inflated_budget                                       5.93255e+07
# budget_cat                                             HighBudget
# inflated_boxoffice                                    3.35354e+07
# year_q_bin                                                      2
# rank                                                            3
# production_company_bin                                       Top5
#
#                                                                    6    \
# brand_ods_id                                                     13731
# replace                          The Hunger Games: Mockingjay - Part 2
# released_on                                                 2015-11-20
# ticker_symbol                                                    LGF.A
# genres                                       Adventure, Sci Fi, Action
# data_profile_dcs_uid                  02b7c6aa78a2cd57bd043918c5d5e8c2
# data_profile_channel_type                                      twitter
# data_profile_source_type                                   search_term
# data_affiliation_active_flag                                         t
# data_affiliation_start_date_key                                    101
# data_affiliation_end_date_key                                     7769
# genre_list                           ['Adventure', 'Sci Fi', 'Action']
# top_genre                                                    Adventure
# released_year                                                     2015
# year_bin                                                             5
# budget                                                         1.6e+08
# production_company                                           Lionsgate
# rating                                                           PG-13
# source                                                    Not Original
# franchise                                                          Yes
# DomesticGross                                                281723902
# genre_grouped                                                Adventure
# inflated_budget                                            1.72583e+08
# budget_cat                                                  HighBudget
# inflated_boxoffice                                          3.0388e+08
# year_q_bin                                                           2
# rank                                                                19
# production_company_bin                                          Top100
#
#                                                                7    \
# brand_ods_id                                                 10681
# replace                                         Terminator Genisys
# released_on                                             2015-07-01
# ticker_symbol                                                  VIA
# genres                                   Adventure, Action, Sci Fi
# data_profile_dcs_uid              d2f99b8dac22b2e68723d8a66d422a2e
# data_profile_channel_type                                  twitter
# data_profile_source_type                               search_term
# data_affiliation_active_flag                                     t
# data_affiliation_start_date_key                                101
# data_affiliation_end_date_key                                 7769
# genre_list                       ['Adventure', 'Action', 'Sci Fi']
# top_genre                                                Adventure
# released_year                                                 2015
# year_bin                                                         5
# budget                                                    1.55e+08
# production_company                              Paramount Pictures
# rating                                                       PG-13
# source                                                    Original
# franchise                                                      Yes
# DomesticGross                                            440600000
# genre_grouped                                            Adventure
# inflated_budget                                         1.6719e+08
# budget_cat                                              HighBudget
# inflated_boxoffice                                     4.75251e+08
# year_q_bin                                                       2
# rank                                                             6
# production_company_bin                                      Top100
#
#                                                               8    \
# brand_ods_id                                                10645
# replace                                      Fifty Shades of Grey
# released_on                                            2015-02-13
# ticker_symbol                                               CMCSA
# genres                                             Romance, Drama
# data_profile_dcs_uid             d42138ae16d3c385c9dd963d5da3c006
# data_profile_channel_type                                facebook
# data_profile_source_type                              search_term
# data_affiliation_active_flag                                    t
# data_affiliation_start_date_key                               101
# data_affiliation_end_date_key                                7769
# genre_list                                   ['Romance', 'Drama']
# top_genre                                                 Romance
# released_year                                                2015
# year_bin                                                        5
# budget                                                      4e+07
# production_company                             Universal Pictures
# rating                                                          R
# source                                               Not Original
# franchise                                                     Yes
# DomesticGross                                           166167230
# genre_grouped                                               Drama
# inflated_budget                                       4.31458e+07
# budget_cat                                           MediumBudget
# inflated_boxoffice                                    1.79236e+08
# year_q_bin                                                      2
# rank                                                            3
# production_company_bin                                       Top5
#
#                                                               9    ...  \
# brand_ods_id                                                16912  ...
# replace                                The Huntsman: Winter's War  ...
# released_on                                            2016-04-22  ...
# ticker_symbol                                               CMCSA  ...
# genres                                   Adventure, Action, Drama  ...
# data_profile_dcs_uid             cdec6aa592e773c0a06c1a18475c9137  ...
# data_profile_channel_type                                 twitter  ...
# data_profile_source_type                                   handle  ...
# data_affiliation_active_flag                                    t  ...
# data_affiliation_start_date_key                               101  ...
# data_affiliation_end_date_key                                7769  ...
# genre_list                       ['Adventure', 'Action', 'Drama']  ...
# top_genre                                               Adventure  ...
# released_year                                                2016  ...
# year_bin                                                        6  ...
# budget                                                   1.15e+08  ...
# production_company                             Universal Pictures  ...
# rating                                                      PG-13  ...
# source                                               Not Original  ...
# franchise                                                     Yes  ...
# DomesticGross                                           165000000  ...
# genre_grouped                                           Adventure  ...
# inflated_budget                                       1.22499e+08  ...
# budget_cat                                             HighBudget  ...
# inflated_boxoffice                                    1.75759e+08  ...
# year_q_bin                                                      2  ...
# rank                                                            3  ...
# production_company_bin                                       Top5  ...
#
#                                                               516  \
# brand_ods_id                                                59691
# replace                                               Black Swan*
# released_on                                            2010-12-03
# ticker_symbol                                                FOXA
# genres                                            Thriller, Drama
# data_profile_dcs_uid             13c906697907a19e15c101ba4beb4398
# data_profile_channel_type                                facebook
# data_profile_source_type                                     page
# data_affiliation_active_flag                                    t
# data_affiliation_start_date_key                               101
# data_affiliation_end_date_key                                7769
# genre_list                                  ['Thriller', 'Drama']
# top_genre                                                Thriller
# released_year                                                2010
# year_bin                                                        1
# budget                                                    1.3e+07
# production_company                       Fox Searchlight Pictures
# rating                                                          R
# source                                                   Original
# franchise                                                      No
# DomesticGross                                          3304000000
# genre_grouped                                            Thriller
# inflated_budget                                       1.52417e+07
# budget_cat                                           MediumBudget
# inflated_boxoffice                                    3.87375e+09
# year_q_bin                                                      1
# rank                                                           79
# production_company_bin                                     Top100
#
#                                                                   517  \
# brand_ods_id                                                    61426
# replace                                                 Despicable Me
# released_on                                                2010-07-09
# ticker_symbol                                                   CMCSA
# genres                                   Animation, Adventure, Comedy
# data_profile_dcs_uid                 4bfb80ed5d2473a1b24f5f6a094644fe
# data_profile_channel_type                                     twitter
# data_profile_source_type                                       handle
# data_affiliation_active_flag                                        t
# data_affiliation_start_date_key                                   101
# data_affiliation_end_date_key                                    7769
# genre_list                       ['Animation', 'Adventure', 'Comedy']
# top_genre                                                   Animation
# released_year                                                    2010
# year_bin                                                            1
# budget                                                        6.9e+07
# production_company                                 Universal Pictures
# rating                                                             PG
# source                                                       Original
# franchise                                                         Yes
# DomesticGross                                               251513985
# genre_grouped                                                  Family
# inflated_budget                                           8.08985e+07
# budget_cat                                                 HighBudget
# inflated_boxoffice                                        2.94886e+08
# year_q_bin                                                          1
# rank                                                                3
# production_company_bin                                           Top5
#
#                                                               518  \
# brand_ods_id                                               130372
# replace                                                    My Spy
# released_on                                            2020-04-17
# ticker_symbol                                                 NaN
# genres                                             Action, Comedy
# data_profile_dcs_uid             10ac71b97dcb9afb2c037ebbf5b9363c
# data_profile_channel_type                                 twitter
# data_profile_source_type                              search_term
# data_affiliation_active_flag                                    t
# data_affiliation_start_date_key                               101
# data_affiliation_end_date_key                                7769
# genre_list                                   ['Action', 'Comedy']
# top_genre                                                  Action
# released_year                                                2020
# year_bin                                                       10
# budget                                                    1.8e+07
# production_company                                 Amazon Studios
# rating                                                      PG-13
# source                                                   Original
# franchise                                                      No
# DomesticGross                                                   0
# genre_grouped                                              Action
# inflated_budget                                           1.8e+07
# budget_cat                                           MediumBudget
# inflated_boxoffice                                              0
# year_q_bin                                                      5
# rank                                                          482
# production_company_bin                                    Top100+
#
#                                                               519  \
# brand_ods_id                                                77544
# replace                                                  Cold War
# released_on                                            2018-12-21
# ticker_symbol                                                AMZN
# genres                                                      Drama
# data_profile_dcs_uid             db3946e1f0a37830a23056e1fe3d6047
# data_profile_channel_type                               instagram
# data_profile_source_type                                     page
# data_affiliation_active_flag                                    t
# data_affiliation_start_date_key                               101
# data_affiliation_end_date_key                                7769
# genre_list                                              ['Drama']
# top_genre                                                   Drama
# released_year                                                2018
# year_bin                                                        8
# budget                                                    4.8e+06
# production_company                                      Opus Film
# rating                                                          R
# source                                                   Original
# franchise                                                     Yes
# DomesticGross                                           205000000
# genre_grouped                                               Drama
# inflated_budget                                       4.88699e+06
# budget_cat                                              LowBudget
# inflated_boxoffice                                    2.08715e+08
# year_q_bin                                                      3
# rank                                                         2294
# production_company_bin                                    Top100+
#
#                                                                   520  \
# brand_ods_id                                                    91708
# replace                                             Trolls World Tour
# released_on                                                2020-04-10
# ticker_symbol                                                   CMCSA
# genres                                   Comedy, Adventure, Animation
# data_profile_dcs_uid                 960854b0b172319f9c1e0ba6ca32bfa2
# data_profile_channel_type                                     twitter
# data_profile_source_type                                       handle
# data_affiliation_active_flag                                        t
# data_affiliation_start_date_key                                   101
# data_affiliation_end_date_key                                    7769
# genre_list                       ['Comedy', 'Adventure', 'Animation']
# top_genre                                                      Comedy
# released_year                                                    2020
# year_bin                                                           10
# budget                                                        9.5e+07
# production_company                                DreamWorks Pictures
# rating                                                             PG
# source                                                       Original
# franchise                                                         Yes
# DomesticGross                                               160800000
# genre_grouped                                                  Comedy
# inflated_budget                                               9.5e+07
# budget_cat                                                 HighBudget
# inflated_boxoffice                                          1.608e+08
# year_q_bin                                                          5
# rank                                                                9
# production_company_bin                                         Top100
#
#                                                               521  \
# brand_ods_id                                                10654
# replace                                                Cinderella
# released_on                                            2015-03-13
# ticker_symbol                                                 DIS
# genres                                   Family, Adventure, Drama
# data_profile_dcs_uid             f185a47fcfc894333ffab8787cefbb38
# data_profile_channel_type                                facebook
# data_profile_source_type                              search_term
# data_affiliation_active_flag                                    t
# data_affiliation_start_date_key                               101
# data_affiliation_end_date_key                                7769
# genre_list                       ['Family', 'Adventure', 'Drama']
# top_genre                                                  Family
# released_year                                                2015
# year_bin                                                        5
# budget                                                   9.75e+07
# production_company                                  Sony Pictures
# rating                                                         PG
# source                                                     Remake
# franchise                                                      No
# DomesticGross                                           201151353
# genre_grouped                                              Family
# inflated_budget                                       1.05168e+08
# budget_cat                                             HighBudget
# inflated_boxoffice                                    2.16971e+08
# year_q_bin                                                      2
# rank                                                          193
# production_company_bin                                    Top100+
#
#                                                               522  \
# brand_ods_id                                                12271
# replace                                                      Chef
# released_on                                            2014-05-30
# ticker_symbol                                                 NaN
# genres                                                     Comedy
# data_profile_dcs_uid             252ba9809bbbd483ff9de63de583b4a5
# data_profile_channel_type                                 twitter
# data_profile_source_type                              search_term
# data_affiliation_active_flag                                    t
# data_affiliation_start_date_key                               101
# data_affiliation_end_date_key                                7769
# genre_list                                             ['Comedy']
# top_genre                                                  Comedy
# released_year                                                2014
# year_bin                                                        4
# budget                                                    1.1e+07
# production_company                             Eros Entertainment
# rating                                                          R
# source                                                     Remake
# franchise                                                      No
# DomesticGross                                            46000000
# genre_grouped                                              Comedy
# inflated_budget                                       1.18792e+07
# budget_cat                                           MediumBudget
# inflated_boxoffice                                    4.96766e+07
# year_q_bin                                                      1
# rank                                                         3211
# production_company_bin                                    Top100+
#
#                                                               523  \
# brand_ods_id                                                41315
# replace                                    A Street Cat Named Bob
# released_on                                            2016-11-18
# ticker_symbol                                                 NaN
# genres                                                     Comedy
# data_profile_dcs_uid             51dd6b2835268213e6e0a420e18df54a
# data_profile_channel_type                                 twitter
# data_profile_source_type                              search_term
# data_affiliation_active_flag                                    t
# data_affiliation_start_date_key                               101
# data_affiliation_end_date_key                                7769
# genre_list                                             ['Comedy']
# top_genre                                                  Comedy
# released_year                                                2016
# year_bin                                                        6
# budget                                                      8e+06
# production_company                        Cleopatra Entertainment
# rating                                                      PG-13
# source                                               Not Original
# franchise                                                      No
# DomesticGross                                               82703
# genre_grouped                                              Comedy
# inflated_budget                                       8.52166e+06
# budget_cat                                           MediumBudget
# inflated_boxoffice                                        88095.9
# year_q_bin                                                      2
# rank                                                        12151
# production_company_bin                                    Top100+
#
#                                                               524  \
# brand_ods_id                                                60789
# replace                                     Behind the Candelabra
# released_on                                            2013-01-26
# ticker_symbol                                                 NaN
# genres                                           Biography, Drama
# data_profile_dcs_uid             5d34d89665f81063456c39e2abfc4ab5
# data_profile_channel_type                                 twitter
# data_profile_source_type                              search_term
# data_affiliation_active_flag                                    t
# data_affiliation_start_date_key                               101
# data_affiliation_end_date_key                                7769
# genre_list                                 ['Biography', 'Drama']
# top_genre                                               Biography
# released_year                                                2013
# year_bin                                                        3
# budget                                                    2.3e+07
# production_company                                      HBO Films
# rating                                                          R
# source                                               Not Original
# franchise                                                      No
# DomesticGross                                             1310896
# genre_grouped                                         Documentary
# inflated_budget                                       2.52412e+07
# budget_cat                                           MediumBudget
# inflated_boxoffice                                    1.43864e+06
# year_q_bin                                                      1
# rank                                                          246
# production_company_bin                                    Top100+
#
#                                                                        525
# brand_ods_id                                                         60626
# replace                                                             Looper
# released_on                                                     2012-09-28
# ticker_symbol                                                          NaN
# genres                                     Crime, Action, Thriller, Sci Fi
# data_profile_dcs_uid                      32840ec68dba0b7de0afdb796eccf0f6
# data_profile_channel_type                                          twitter
# data_profile_source_type                                       search_term
# data_affiliation_active_flag                                             t
# data_affiliation_start_date_key                                        101
# data_affiliation_end_date_key                                         7769
# genre_list                       ['Crime', 'Action', 'Thriller', 'Sci Fi']
# top_genre                                                            Crime
# released_year                                                         2012
# year_bin                                                                 2
# budget                                                               3e+07
# production_company                                           Sony Pictures
# rating                                                                   R
# source                                                            Original
# franchise                                                               No
# DomesticGross                                                     66486205
# genre_grouped                                                     Thriller
# inflated_budget                                                3.34056e+07
# budget_cat                                                    MediumBudget
# inflated_boxoffice                                             7.40337e+07
# year_q_bin                                                               1
# rank                                                                   193
# production_company_bin                                             Top100+
#
# [28 rows x 526 columns]

# %% [markdown]
# ## Z-scale inflated_budget

# %%
budget_scale = StandardScaler()

# %%
pickle.dump(budget_scale, open('budget_scale.pkl', 'wb'))

# %%
brand_extras['inflated_budget'] = budget_scale.fit_transform(brand_extras['inflated_budget'].values.reshape(-1, 1))

# %%
brand_extras.T
# Out:
#                                                               0    \
# brand_ods_id                                                41301
# replace                                         Blade Runner 2049
# released_on                                            2017-10-06
# ticker_symbol                                                   T
# genres                                                     Sci Fi
# data_profile_dcs_uid             45b03b4ab3e6e5781426f83613af0807
# data_profile_channel_type                               instagram
# data_profile_source_type                                     page
# data_affiliation_active_flag                                    t
# data_affiliation_start_date_key                               101
# data_affiliation_end_date_key                                7769
# genre_list                                             ['Sci Fi']
# top_genre                                                  Sci Fi
# released_year                                                2017
# year_bin                                                        7
# budget                                                   1.85e+08
# production_company                                   Warner Bros.
# rating                                                          R
# source                                                     Remake
# franchise                                                     Yes
# DomesticGross                                            92054159
# genre_grouped                                             Fantasy
# inflated_budget                                           1.79864
# budget_cat                                             HighBudget
# inflated_boxoffice                                    9.60116e+07
# year_q_bin                                                      3
# rank                                                            1
# production_company_bin                                       Top5
#
#                                                               1    \
# brand_ods_id                                                25859
# replace                                                  Geostorm
# released_on                                            2017-10-20
# ticker_symbol                                                   T
# genres                                             Action, Sci Fi
# data_profile_dcs_uid             ea5eb96fa2d53c68a7fec4a76636c6ff
# data_profile_channel_type                                 twitter
# data_profile_source_type                              search_term
# data_affiliation_active_flag                                    t
# data_affiliation_start_date_key                               101
# data_affiliation_end_date_key                                7769
# genre_list                                   ['Action', 'Sci Fi']
# top_genre                                                  Action
# released_year                                                2017
# year_bin                                                        7
# budget                                                      1e+08
# production_company                                   Warner Bros.
# rating                                                      PG-13
# source                                                   Original
# franchise                                                      No
# DomesticGross                                            33700160
# genre_grouped                                              Action
# inflated_budget                                          0.531992
# budget_cat                                             HighBudget
# inflated_boxoffice                                    3.51489e+07
# year_q_bin                                                      3
# rank                                                            1
# production_company_bin                                       Top5
#
#                                                               2    \
# brand_ods_id                                                44895
# replace                                          Ready Player One
# released_on                                            2018-03-29
# ticker_symbol                                                   T
# genres                                   Sci Fi, Action, Thriller
# data_profile_dcs_uid             31e9bbe160e77e8558e35bb5c5bd7089
# data_profile_channel_type                                facebook
# data_profile_source_type                              search_term
# data_affiliation_active_flag                                    t
# data_affiliation_start_date_key                               101
# data_affiliation_end_date_key                                7769
# genre_list                       ['Sci Fi', 'Action', 'Thriller']
# top_genre                                                  Sci Fi
# released_year                                                2018
# year_bin                                                        8
# budget                                                    1.5e+08
# production_company                                   Warner Bros.
# rating                                                      PG-13
# source                                               Not Original
# franchise                                                      No
# DomesticGross                                           137690172
# genre_grouped                                             Fantasy
# inflated_budget                                           1.22378
# budget_cat                                             HighBudget
# inflated_boxoffice                                    1.40185e+08
# year_q_bin                                                      3
# rank                                                            1
# production_company_bin                                       Top5
#
#                                                               3    \
# brand_ods_id                                                10617
# replace                                                      Fury
# released_on                                            2014-10-17
# ticker_symbol                                                 NaN
# genres                                         Action, Drama, War
# data_profile_dcs_uid             6c7dc49a1cece02cc80d0826e6424df2
# data_profile_channel_type                                facebook
# data_profile_source_type                              search_term
# data_affiliation_active_flag                                    t
# data_affiliation_start_date_key                               101
# data_affiliation_end_date_key                                7769
# genre_list                             ['Action', 'Drama', 'War']
# top_genre                                                  Action
# released_year                                                2014
# year_bin                                                        4
# budget                                                      8e+07
# production_company                                  Sony Pictures
# rating                                                          R
# source                                                   Original
# franchise                                                      No
# DomesticGross                                            85817906
# genre_grouped                                              Action
# inflated_budget                                          0.276174
# budget_cat                                             HighBudget
# inflated_boxoffice                                    9.26769e+07
# year_q_bin                                                      1
# rank                                                          193
# production_company_bin                                    Top100+
#
#                                                               4    \
# brand_ods_id                                                10607
# replace                                              Nightcrawler
# released_on                                            2014-10-31
# ticker_symbol                                                 NaN
# genres                                     Crime, Thriller, Drama
# data_profile_dcs_uid             aaec8ee14f2e372b8e35a72ee9613ca1
# data_profile_channel_type                                 twitter
# data_profile_source_type                              search_term
# data_affiliation_active_flag                                    t
# data_affiliation_start_date_key                               101
# data_affiliation_end_date_key                                7769
# genre_list                         ['Crime', 'Thriller', 'Drama']
# top_genre                                                   Crime
# released_year                                                2014
# year_bin                                                        4
# budget                                                    8.5e+06
# production_company                                Open Road Films
# rating                                                          R
# source                                                   Original
# franchise                                                      No
# DomesticGross                                            32381218
# genre_grouped                                            Thriller
# inflated_budget                                         -0.827031
# budget_cat                                           MediumBudget
# inflated_boxoffice                                    3.49693e+07
# year_q_bin                                                      1
# rank                                                          223
# production_company_bin                                    Top100+
#
#                                                               5    \
# brand_ods_id                                                13370
# replace                                              Crimson Peak
# released_on                                            2015-10-16
# ticker_symbol                                               CMCSA
# genres                                                     Horror
# data_profile_dcs_uid             7034ae8af3651572a1622a96f47334b4
# data_profile_channel_type                                 twitter
# data_profile_source_type                              search_term
# data_affiliation_active_flag                                    t
# data_affiliation_start_date_key                               101
# data_affiliation_end_date_key                                7769
# genre_list                                             ['Horror']
# top_genre                                                  Horror
# released_year                                                2015
# year_bin                                                        5
# budget                                                    5.5e+07
# production_company                             Universal Pictures
# rating                                                          R
# source                                                   Original
# franchise                                                      No
# DomesticGross                                            31090320
# genre_grouped                                              Horror
# inflated_budget                                         -0.110568
# budget_cat                                             HighBudget
# inflated_boxoffice                                    3.35354e+07
# year_q_bin                                                      2
# rank                                                            3
# production_company_bin                                       Top5
#
#                                                                    6    \
# brand_ods_id                                                     13731
# replace                          The Hunger Games: Mockingjay - Part 2
# released_on                                                 2015-11-20
# ticker_symbol                                                    LGF.A
# genres                                       Adventure, Sci Fi, Action
# data_profile_dcs_uid                  02b7c6aa78a2cd57bd043918c5d5e8c2
# data_profile_channel_type                                      twitter
# data_profile_source_type                                   search_term
# data_affiliation_active_flag                                         t
# data_affiliation_start_date_key                                    101
# data_affiliation_end_date_key                                     7769
# genre_list                           ['Adventure', 'Sci Fi', 'Action']
# top_genre                                                    Adventure
# released_year                                                     2015
# year_bin                                                             5
# budget                                                         1.6e+08
# production_company                                           Lionsgate
# rating                                                           PG-13
# source                                                    Not Original
# franchise                                                          Yes
# DomesticGross                                                281723902
# genre_grouped                                                Adventure
# inflated_budget                                                 1.5076
# budget_cat                                                  HighBudget
# inflated_boxoffice                                          3.0388e+08
# year_q_bin                                                           2
# rank                                                                19
# production_company_bin                                          Top100
#
#                                                                7    \
# brand_ods_id                                                 10681
# replace                                         Terminator Genisys
# released_on                                             2015-07-01
# ticker_symbol                                                  VIA
# genres                                   Adventure, Action, Sci Fi
# data_profile_dcs_uid              d2f99b8dac22b2e68723d8a66d422a2e
# data_profile_channel_type                                  twitter
# data_profile_source_type                               search_term
# data_affiliation_active_flag                                     t
# data_affiliation_start_date_key                                101
# data_affiliation_end_date_key                                 7769
# genre_list                       ['Adventure', 'Action', 'Sci Fi']
# top_genre                                                Adventure
# released_year                                                 2015
# year_bin                                                         5
# budget                                                    1.55e+08
# production_company                              Paramount Pictures
# rating                                                       PG-13
# source                                                    Original
# franchise                                                      Yes
# DomesticGross                                            440600000
# genre_grouped                                            Adventure
# inflated_budget                                            1.43055
# budget_cat                                              HighBudget
# inflated_boxoffice                                     4.75251e+08
# year_q_bin                                                       2
# rank                                                             6
# production_company_bin                                      Top100
#
#                                                               8    \
# brand_ods_id                                                10645
# replace                                      Fifty Shades of Grey
# released_on                                            2015-02-13
# ticker_symbol                                               CMCSA
# genres                                             Romance, Drama
# data_profile_dcs_uid             d42138ae16d3c385c9dd963d5da3c006
# data_profile_channel_type                                facebook
# data_profile_source_type                              search_term
# data_affiliation_active_flag                                    t
# data_affiliation_start_date_key                               101
# data_affiliation_end_date_key                                7769
# genre_list                                   ['Romance', 'Drama']
# top_genre                                                 Romance
# released_year                                                2015
# year_bin                                                        5
# budget                                                      4e+07
# production_company                             Universal Pictures
# rating                                                          R
# source                                               Not Original
# franchise                                                     Yes
# DomesticGross                                           166167230
# genre_grouped                                               Drama
# inflated_budget                                         -0.341735
# budget_cat                                           MediumBudget
# inflated_boxoffice                                    1.79236e+08
# year_q_bin                                                      2
# rank                                                            3
# production_company_bin                                       Top5
#
#                                                               9    ...  \
# brand_ods_id                                                16912  ...
# replace                                The Huntsman: Winter's War  ...
# released_on                                            2016-04-22  ...
# ticker_symbol                                               CMCSA  ...
# genres                                   Adventure, Action, Drama  ...
# data_profile_dcs_uid             cdec6aa592e773c0a06c1a18475c9137  ...
# data_profile_channel_type                                 twitter  ...
# data_profile_source_type                                   handle  ...
# data_affiliation_active_flag                                    t  ...
# data_affiliation_start_date_key                               101  ...
# data_affiliation_end_date_key                                7769  ...
# genre_list                       ['Adventure', 'Action', 'Drama']  ...
# top_genre                                               Adventure  ...
# released_year                                                2016  ...
# year_bin                                                        6  ...
# budget                                                   1.15e+08  ...
# production_company                             Universal Pictures  ...
# rating                                                      PG-13  ...
# source                                               Not Original  ...
# franchise                                                     Yes  ...
# DomesticGross                                           165000000  ...
# genre_grouped                                           Adventure  ...
# inflated_budget                                          0.792022  ...
# budget_cat                                             HighBudget  ...
# inflated_boxoffice                                    1.75759e+08  ...
# year_q_bin                                                      2  ...
# rank                                                            3  ...
# production_company_bin                                       Top5  ...
#
#                                                               516  \
# brand_ods_id                                                59691
# replace                                               Black Swan*
# released_on                                            2010-12-03
# ticker_symbol                                                FOXA
# genres                                            Thriller, Drama
# data_profile_dcs_uid             13c906697907a19e15c101ba4beb4398
# data_profile_channel_type                                facebook
# data_profile_source_type                                     page
# data_affiliation_active_flag                                    t
# data_affiliation_start_date_key                               101
# data_affiliation_end_date_key                                7769
# genre_list                                  ['Thriller', 'Drama']
# top_genre                                                Thriller
# released_year                                                2010
# year_bin                                                        1
# budget                                                    1.3e+07
# production_company                       Fox Searchlight Pictures
# rating                                                          R
# source                                                   Original
# franchise                                                      No
# DomesticGross                                          3304000000
# genre_grouped                                            Thriller
# inflated_budget                                         -0.740415
# budget_cat                                           MediumBudget
# inflated_boxoffice                                    3.87375e+09
# year_q_bin                                                      1
# rank                                                           79
# production_company_bin                                     Top100
#
#                                                                   517  \
# brand_ods_id                                                    61426
# replace                                                 Despicable Me
# released_on                                                2010-07-09
# ticker_symbol                                                   CMCSA
# genres                                   Animation, Adventure, Comedy
# data_profile_dcs_uid                 4bfb80ed5d2473a1b24f5f6a094644fe
# data_profile_channel_type                                     twitter
# data_profile_source_type                                       handle
# data_affiliation_active_flag                                        t
# data_affiliation_start_date_key                                   101
# data_affiliation_end_date_key                                    7769
# genre_list                       ['Animation', 'Adventure', 'Comedy']
# top_genre                                                   Animation
# released_year                                                    2010
# year_bin                                                            1
# budget                                                        6.9e+07
# production_company                                 Universal Pictures
# rating                                                             PG
# source                                                       Original
# franchise                                                         Yes
# DomesticGross                                               251513985
# genre_grouped                                                  Family
# inflated_budget                                              0.197656
# budget_cat                                                 HighBudget
# inflated_boxoffice                                        2.94886e+08
# year_q_bin                                                          1
# rank                                                                3
# production_company_bin                                           Top5
#
#                                                               518  \
# brand_ods_id                                               130372
# replace                                                    My Spy
# released_on                                            2020-04-17
# ticker_symbol                                                 NaN
# genres                                             Action, Comedy
# data_profile_dcs_uid             10ac71b97dcb9afb2c037ebbf5b9363c
# data_profile_channel_type                                 twitter
# data_profile_source_type                              search_term
# data_affiliation_active_flag                                    t
# data_affiliation_start_date_key                               101
# data_affiliation_end_date_key                                7769
# genre_list                                   ['Action', 'Comedy']
# top_genre                                                  Action
# released_year                                                2020
# year_bin                                                       10
# budget                                                    1.8e+07
# production_company                                 Amazon Studios
# rating                                                      PG-13
# source                                                   Original
# franchise                                                      No
# DomesticGross                                                   0
# genre_grouped                                              Action
# inflated_budget                                         -0.701006
# budget_cat                                           MediumBudget
# inflated_boxoffice                                              0
# year_q_bin                                                      5
# rank                                                          482
# production_company_bin                                    Top100+
#
#                                                               519  \
# brand_ods_id                                                77544
# replace                                                  Cold War
# released_on                                            2018-12-21
# ticker_symbol                                                AMZN
# genres                                                      Drama
# data_profile_dcs_uid             db3946e1f0a37830a23056e1fe3d6047
# data_profile_channel_type                               instagram
# data_profile_source_type                                     page
# data_affiliation_active_flag                                    t
# data_affiliation_start_date_key                               101
# data_affiliation_end_date_key                                7769
# genre_list                                              ['Drama']
# top_genre                                                   Drama
# released_year                                                2018
# year_bin                                                        8
# budget                                                    4.8e+06
# production_company                                      Opus Film
# rating                                                          R
# source                                                   Original
# franchise                                                     Yes
# DomesticGross                                           205000000
# genre_grouped                                               Drama
# inflated_budget                                         -0.888358
# budget_cat                                              LowBudget
# inflated_boxoffice                                    2.08715e+08
# year_q_bin                                                      3
# rank                                                         2294
# production_company_bin                                    Top100+
#
#                                                                   520  \
# brand_ods_id                                                    91708
# replace                                             Trolls World Tour
# released_on                                                2020-04-10
# ticker_symbol                                                   CMCSA
# genres                                   Comedy, Adventure, Animation
# data_profile_dcs_uid                 960854b0b172319f9c1e0ba6ca32bfa2
# data_profile_channel_type                                     twitter
# data_profile_source_type                                       handle
# data_affiliation_active_flag                                        t
# data_affiliation_start_date_key                                   101
# data_affiliation_end_date_key                                    7769
# genre_list                       ['Comedy', 'Adventure', 'Animation']
# top_genre                                                      Comedy
# released_year                                                    2020
# year_bin                                                           10
# budget                                                        9.5e+07
# production_company                                DreamWorks Pictures
# rating                                                             PG
# source                                                       Original
# franchise                                                         Yes
# DomesticGross                                               160800000
# genre_grouped                                                  Comedy
# inflated_budget                                              0.399132
# budget_cat                                                 HighBudget
# inflated_boxoffice                                          1.608e+08
# year_q_bin                                                          5
# rank                                                                9
# production_company_bin                                         Top100
#
#                                                               521  \
# brand_ods_id                                                10654
# replace                                                Cinderella
# released_on                                            2015-03-13
# ticker_symbol                                                 DIS
# genres                                   Family, Adventure, Drama
# data_profile_dcs_uid             f185a47fcfc894333ffab8787cefbb38
# data_profile_channel_type                                facebook
# data_profile_source_type                              search_term
# data_affiliation_active_flag                                    t
# data_affiliation_start_date_key                               101
# data_affiliation_end_date_key                                7769
# genre_list                       ['Family', 'Adventure', 'Drama']
# top_genre                                                  Family
# released_year                                                2015
# year_bin                                                        5
# budget                                                   9.75e+07
# production_company                                  Sony Pictures
# rating                                                         PG
# source                                                     Remake
# franchise                                                      No
# DomesticGross                                           201151353
# genre_grouped                                              Family
# inflated_budget                                          0.544407
# budget_cat                                             HighBudget
# inflated_boxoffice                                    2.16971e+08
# year_q_bin                                                      2
# rank                                                          193
# production_company_bin                                    Top100+
#
#                                                               522  \
# brand_ods_id                                                12271
# replace                                                      Chef
# released_on                                            2014-05-30
# ticker_symbol                                                 NaN
# genres                                                     Comedy
# data_profile_dcs_uid             252ba9809bbbd483ff9de63de583b4a5
# data_profile_channel_type                                 twitter
# data_profile_source_type                              search_term
# data_affiliation_active_flag                                    t
# data_affiliation_start_date_key                               101
# data_affiliation_end_date_key                                7769
# genre_list                                             ['Comedy']
# top_genre                                                  Comedy
# released_year                                                2014
# year_bin                                                        4
# budget                                                    1.1e+07
# production_company                             Eros Entertainment
# rating                                                          R
# source                                                     Remake
# franchise                                                      No
# DomesticGross                                            46000000
# genre_grouped                                              Comedy
# inflated_budget                                         -0.788457
# budget_cat                                           MediumBudget
# inflated_boxoffice                                    4.96766e+07
# year_q_bin                                                      1
# rank                                                         3211
# production_company_bin                                    Top100+
#
#                                                               523  \
# brand_ods_id                                                41315
# replace                                    A Street Cat Named Bob
# released_on                                            2016-11-18
# ticker_symbol                                                 NaN
# genres                                                     Comedy
# data_profile_dcs_uid             51dd6b2835268213e6e0a420e18df54a
# data_profile_channel_type                                 twitter
# data_profile_source_type                              search_term
# data_affiliation_active_flag                                    t
# data_affiliation_start_date_key                               101
# data_affiliation_end_date_key                                7769
# genre_list                                             ['Comedy']
# top_genre                                                  Comedy
# released_year                                                2016
# year_bin                                                        6
# budget                                                      8e+06
# production_company                        Cleopatra Entertainment
# rating                                                      PG-13
# source                                               Not Original
# franchise                                                      No
# DomesticGross                                               82703
# genre_grouped                                              Comedy
# inflated_budget                                         -0.836428
# budget_cat                                           MediumBudget
# inflated_boxoffice                                        88095.9
# year_q_bin                                                      2
# rank                                                        12151
# production_company_bin                                    Top100+
#
#                                                               524  \
# brand_ods_id                                                60789
# replace                                     Behind the Candelabra
# released_on                                            2013-01-26
# ticker_symbol                                                 NaN
# genres                                           Biography, Drama
# data_profile_dcs_uid             5d34d89665f81063456c39e2abfc4ab5
# data_profile_channel_type                                 twitter
# data_profile_source_type                              search_term
# data_affiliation_active_flag                                    t
# data_affiliation_start_date_key                               101
# data_affiliation_end_date_key                                7769
# genre_list                                 ['Biography', 'Drama']
# top_genre                                               Biography
# released_year                                                2013
# year_bin                                                        3
# budget                                                    2.3e+07
# production_company                                      HBO Films
# rating                                                          R
# source                                               Not Original
# franchise                                                      No
# DomesticGross                                             1310896
# genre_grouped                                         Documentary
# inflated_budget                                         -0.597547
# budget_cat                                           MediumBudget
# inflated_boxoffice                                    1.43864e+06
# year_q_bin                                                      1
# rank                                                          246
# production_company_bin                                    Top100+
#
#                                                                        525
# brand_ods_id                                                         60626
# replace                                                             Looper
# released_on                                                     2012-09-28
# ticker_symbol                                                          NaN
# genres                                     Crime, Action, Thriller, Sci Fi
# data_profile_dcs_uid                      32840ec68dba0b7de0afdb796eccf0f6
# data_profile_channel_type                                          twitter
# data_profile_source_type                                       search_term
# data_affiliation_active_flag                                             t
# data_affiliation_start_date_key                                        101
# data_affiliation_end_date_key                                         7769
# genre_list                       ['Crime', 'Action', 'Thriller', 'Sci Fi']
# top_genre                                                            Crime
# released_year                                                         2012
# year_bin                                                                 2
# budget                                                               3e+07
# production_company                                           Sony Pictures
# rating                                                                   R
# source                                                            Original
# franchise                                                               No
# DomesticGross                                                     66486205
# genre_grouped                                                     Thriller
# inflated_budget                                                  -0.480899
# budget_cat                                                    MediumBudget
# inflated_boxoffice                                             7.40337e+07
# year_q_bin                                                               1
# rank                                                                   193
# production_company_bin                                             Top100+
#
# [28 rows x 526 columns]

# %%
pickle.dump(budget_scale, open('budget_scale.pkl', 'wb'))

# %% [markdown]
# ## Select variables for clustering

# %%
clust_brand_extras = brand_extras[['replace', 'top_genre', 'rating', 'source', 'franchise', 'inflated_budget']]

# %%
clust_brand_extras = clust_brand_extras.set_index('replace')

# %%
clust_brand_extras.T
# Out:
# replace         Blade Runner 2049  Geostorm Ready Player One      Fury  \
# top_genre                  Sci Fi    Action           Sci Fi    Action
# rating                          R     PG-13            PG-13         R
# source                     Remake  Original     Not Original  Original
# franchise                     Yes        No               No        No
# inflated_budget           1.79864  0.531992          1.22378  0.276174
#
# replace         Nightcrawler Crimson Peak  \
# top_genre              Crime       Horror
# rating                     R            R
# source              Original     Original
# franchise                 No           No
# inflated_budget    -0.827031    -0.110568
#
# replace         The Hunger Games: Mockingjay - Part 2 Terminator Genisys  \
# top_genre                                   Adventure          Adventure
# rating                                          PG-13              PG-13
# source                                   Not Original           Original
# franchise                                         Yes                Yes
# inflated_budget                                1.5076            1.43055
#
# replace         Fifty Shades of Grey The Huntsman: Winter's War  ...  \
# top_genre                    Romance                  Adventure  ...
# rating                             R                      PG-13  ...
# source                  Not Original               Not Original  ...
# franchise                        Yes                        Yes  ...
# inflated_budget            -0.341735                   0.792022  ...
#
# replace         Black Swan* Despicable Me    My Spy  Cold War  \
# top_genre          Thriller     Animation    Action     Drama
# rating                    R            PG     PG-13         R
# source             Original      Original  Original  Original
# franchise                No           Yes        No       Yes
# inflated_budget   -0.740415      0.197656 -0.701006 -0.888358
#
# replace         Trolls World Tour Cinderella      Chef A Street Cat Named Bob  \
# top_genre                  Comedy     Family    Comedy                 Comedy
# rating                         PG         PG         R                  PG-13
# source                   Original     Remake    Remake           Not Original
# franchise                     Yes         No        No                     No
# inflated_budget          0.399132   0.544407 -0.788457              -0.836428
#
# replace         Behind the Candelabra    Looper
# top_genre                   Biography     Crime
# rating                              R         R
# source                   Not Original  Original
# franchise                          No        No
# inflated_budget             -0.597547 -0.480899
#
# [5 rows x 526 columns]

# %% [markdown]
# ## Factor Analysis of mixed data

# %%
# https://pypi.org/project/prince/#factor-analysis-of-mixed-data-famd
# https://pypi.org/project/light-famd/#factor-analysis-of-mixed-data-famd

# %%
famd = prince.FAMD(n_components = 2)
famd2 = famd.fit(clust_brand_extras)
clust_brand_extras_famd = famd2.row_coordinates(clust_brand_extras)
clust_brand_extras_famd
# Out:
#                                 0          1
# replace
# Blade Runner 2049       21.061685   7.899766
# Geostorm                48.849650  12.932052
# Ready Player One        50.527737 -24.818354
# Fury                    44.521497  41.229056
# Nightcrawler            41.229965  44.332444
# ...                           ...        ...
# Cinderella              25.800320   8.076914
# Chef                    33.813633  26.262578
# A Street Cat Named Bob  53.157765 -20.789204
# Behind the Candelabra   46.024679   4.396919
# Looper                  41.229523  44.327896
#
# [526 rows x 2 columns]

# %% [markdown]
# ## Hierarchical Clustering

# %%
# Silhouette Score
score = []
for n_clusters in list(range(2, 50)):
    hc = AgglomerativeClustering(n_clusters = n_clusters, affinity = 'euclidean', linkage ='ward')
    preds = hc.fit_predict(clust_brand_extras_famd)
    score.append(silhouette_score(clust_brand_extras_famd.values, preds))

# %%
figure(figsize=(15, 10))
plt.plot(list(range(2, 50)), score)
plt.xticks(list(range(2, 50)))
plt.show()

# %% [markdown]
# ## k = 9

# %%
hc = AgglomerativeClustering(n_clusters = 9, affinity = 'euclidean', linkage ='ward')
clusters = hc.fit_predict(clust_brand_extras_famd)

# %%
pickle.dump(hc, open('hc.pkl', 'wb'))

# %%
brand_extras['cluster_id'] = clusters

# %%
brand_extras.to_csv('esther_cluster.csv')

# %%
brand_extras.head(5)
# Out:
#                   top_genre rating        source  franchise  inflated_budget  \
# replace
# Blade Runner 2049    Sci Fi      R        Remake        1.0         1.855106
# Geostorm             Action  PG-13      Original        0.0         0.563000
# Ready Player One     Sci Fi  PG-13  Not Original        0.0         1.268695
# Fury                 Action      R      Original        0.0         0.302040
# Nightcrawler          Crime      R      Original        0.0        -0.823339
#
#                    cluster_id
# replace
# Blade Runner 2049           8
# Geostorm                    4
# Ready Player One            0
# Fury                        1
# Nightcrawler                1

# %%
clust_df = pd.DataFrame(clust_brand_extras['cluster_id'].value_counts())
clust_df
# Out:
#    cluster_id
# 0         151
# 1         106
# 4          85
# 2          77
# 3          61
# 6          53
# 7          11
# 8          10
# 5           9

# %% [markdown]
# ## Cluster 0: Not Original, PG-13

# %%
clust_brand_extras[clust_brand_extras['cluster_id'] == 0]
# Out:
#                                         top_genre rating        source  \
# replace
# Ready Player One                           Sci Fi  PG-13  Not Original
# The Hunger Games: Mockingjay - Part 2   Adventure  PG-13  Not Original
# The Huntsman: Winter's War              Adventure  PG-13  Not Original
# Tolkien                                 Biography  PG-13  Not Original
# Black or White                              Drama  PG-13  Not Original
# ...                                           ...    ...           ...
# Shazam!                                    Action  PG-13  Not Original
# My Hero Academia: Two Heroes            Animation  PG-13  Not Original
# Fast & Furious                             Action  PG-13  Not Original
# To All the Boys: P.S. I Still Love You      Drama  PG-13  Not Original
# A Street Cat Named Bob                     Comedy  PG-13  Not Original
#
#                                         franchise  inflated_budget  cluster_id
# replace
# Ready Player One                              0.0         1.268695           0
# The Hunger Games: Mockingjay - Part 2         1.0         1.558221           0
# The Huntsman: Winter's War                    1.0         0.828256           0
# Tolkien                                       0.0        -0.665631           0
# Black or White                                0.0        -0.815637           0
# ...                                           ...              ...         ...
# Shazam!                                       1.0         0.281722           0
# My Hero Academia: Two Heroes                  1.0        -0.957125           0
# Fast & Furious                                1.0         0.519173           0
# To All the Boys: P.S. I Still Love You        1.0        -0.694781           0
# A Street Cat Named Bob                        0.0        -0.832924           0
#
# [151 rows x 6 columns]

# %% [markdown]
# ## Cluster 1: Original, R (mostly low budget)

# %%
clust_brand_extras[clust_brand_extras['cluster_id'] == 1]
# Out:
#                                 top_genre rating    source  franchise  \
# replace
# Fury                               Action      R  Original        0.0
# Nightcrawler                        Crime      R  Original        0.0
# Crimson Peak                       Horror      R  Original        0.0
# Chappie                            Action      R  Original        0.0
# Booksmart                          Comedy      R  Original        0.0
# ...                                   ...    ...       ...        ...
# Black Swan*                      Thriller      R  Original        0.0
# Cold War                            Drama      R  Original        1.0
# El Camino: A Breaking Bad Movie     Drama      R  Original        0.0
# Looper                              Crime      R  Original        0.0
# Halloween II                       Horror      R  Original        1.0
#
#                                  inflated_budget  cluster_id
# replace
# Fury                                    0.302040           1
# Nightcrawler                           -0.823339           1
# Crimson Peak                           -0.092475           1
# Chappie                                -0.186800           1
# Booksmart                              -0.869677           1
# ...                                          ...         ...
# Black Swan*                            -0.734981           1
# Cold War                               -0.885899           1
# El Camino: A Breaking Bad Movie        -0.855102           1
# Looper                                 -0.470249           1
# Halloween II                           -0.854674           1
#
# [106 rows x 6 columns]

# %% [markdown]
# ## Cluster 2: Not Original, R (mostly low budget)

# %%
clust_brand_extras[clust_brand_extras['cluster_id'] == 2]
# Out:
#                                                       top_genre rating  \
# replace
# Fifty Shades of Grey                                    Romance      R
# Lone Survivor                                          Thriller      R
# The Girl in the Spider's Web: A New Dragon Tatt...        Drama      R
# Fifty Shades Darker                                       Drama      R
# Inside Llewyn Davis                                       Drama      R
# ...                                                         ...    ...
# Honey Boy                                                 Drama      R
# Die Hard*                                                Action      R
# Fight Club*                                               Crime      R
# How to Make Money Selling Drugs                     Documentary      R
# Behind the Candelabra                                 Biography      R
#
#                                                           source  franchise  \
# replace
# Fifty Shades of Grey                                Not Original        1.0
# Lone Survivor                                       Not Original        0.0
# The Girl in the Spider's Web: A New Dragon Tatt...  Not Original        1.0
# Fifty Shades Darker                                 Not Original        1.0
# Inside Llewyn Davis                                 Not Original        0.0
# ...                                                          ...        ...
# Honey Boy                                           Not Original        0.0
# Die Hard*                                           Not Original        1.0
# Fight Club*                                         Not Original        0.0
# How to Make Money Selling Drugs                     Not Original        0.0
# Behind the Candelabra                               Not Original        0.0
#
#                                                     inflated_budget  \
# replace
# Fifty Shades of Grey                                      -0.328288
# Lone Survivor                                             -0.317329
# The Girl in the Spider's Web: A New Dragon Tatt...        -0.319057
# Fifty Shades Darker                                       -0.121056
# Inside Llewyn Davis                                       -0.781181
# ...                                                             ...
# Honey Boy                                                 -0.906114
# Die Hard*                                                 -0.074891
# Fight Club*                                                0.496863
# How to Make Money Selling Drugs                           -0.957125
# Behind the Candelabra                                     -0.589242
#
#                                                     cluster_id
# replace
# Fifty Shades of Grey                                         2
# Lone Survivor                                                2
# The Girl in the Spider's Web: A New Dragon Tatt...           2
# Fifty Shades Darker                                          2
# Inside Llewyn Davis                                          2
# ...                                                        ...
# Honey Boy                                                    2
# Die Hard*                                                    2
# Fight Club*                                                  2
# How to Make Money Selling Drugs                              2
# Behind the Candelabra                                        2
#
# [77 rows x 6 columns]

# %% [markdown]
# ## Cluster 3: Not Original, PG/G

# %%
clust_brand_extras[clust_brand_extras['cluster_id'] == 3]
# Out:
#                                           top_genre rating        source  \
# replace
# Dora and The Lost City of Gold               Action     PG  Not Original
# Teen Titans Go! to the Movies             Animation     PG  Not Original
# The SpongeBob Movie: Sponge Out of Water  Animation     PG  Not Original
# The LEGO NINJAGO Movie                       Action     PG  Not Original
# Heaven Is for Real                            Drama     PG  Not Original
# ...                                             ...    ...           ...
# The Angry Birds Movie                     Animation     PG  Not Original
# The Addams Family (2019)                  Animation     PG  Not Original
# Alvin and the Chipmunks: The Squeakquel*     Comedy     PG  Not Original
# Rocky II                                      Drama     PG  Not Original
# Winnie the Pooh: Springtime with Roo      Animation      G  Not Original
#
#                                           franchise  inflated_budget  \
# replace
# Dora and The Lost City of Gold                  0.0        -0.242966
# Teen Titans Go! to the Movies                   1.0        -0.808737
# The SpongeBob Movie: Sponge Out of Water        1.0         0.206223
# The LEGO NINJAGO Movie                          1.0         0.106962
# Heaven Is for Real                              0.0        -0.768250
# ...                                             ...              ...
# The Angry Birds Movie                           1.0         0.176204
# The Addams Family (2019)                        1.0        -0.607333
# Alvin and the Chipmunks: The Squeakquel*        1.0         0.258650
# Rocky II                                        1.0        -0.597733
# Winnie the Pooh: Springtime with Roo            1.0        -0.957125
#
#                                           cluster_id
# replace
# Dora and The Lost City of Gold                     3
# Teen Titans Go! to the Movies                      3
# The SpongeBob Movie: Sponge Out of Water           3
# The LEGO NINJAGO Movie                             3
# Heaven Is for Real                                 3
# ...                                              ...
# The Angry Birds Movie                              3
# The Addams Family (2019)                           3
# Alvin and the Chipmunks: The Squeakquel*           3
# Rocky II                                           3
# Winnie the Pooh: Springtime with Roo               3
#
# [61 rows x 6 columns]

# %% [markdown]
# ## Cluster 4: Original, PG-13

# %%
clust_brand_extras[clust_brand_extras['cluster_id'] == 4]
# Out:
#                                 top_genre rating    source  franchise  \
# replace
# Geostorm                           Action  PG-13  Original        0.0
# Terminator Genisys              Adventure  PG-13  Original        1.0
# The Expendables 3                Thriller  PG-13  Original        1.0
# War for the Planet of the Apes  Adventure  PG-13  Original        1.0
# Lowriders                           Drama  PG-13  Original        0.0
# ...                                   ...    ...       ...        ...
# Solo: A Star Wars Story         Adventure  PG-13  Original        1.0
# 500 Days of Summer*               Romance  PG-13  Original        0.0
# Dodgeball*                         Comedy  PG-13  Original        0.0
# Edward Scissorhands*              Fantasy  PG-13  Original        0.0
# My Spy                             Action  PG-13  Original        0.0
#
#                                 inflated_budget  cluster_id
# replace
# Geostorm                               0.563000           4
# Terminator Genisys                     1.479616           4
# The Expendables 3                      0.616831           4
# War for the Planet of the Apes         1.353465           4
# Lowriders                             -0.943201           4
# ...                                         ...         ...
# Solo: A Star Wars Story                3.123544           4
# 500 Days of Summer*                   -0.826863           4
# Dodgeball*                            -0.365311           4
# Edward Scissorhands*                  -0.386763           4
# My Spy                                -0.694781           4
#
# [85 rows x 6 columns]

# %% [markdown]
# ## Cluster 5: Remake, PG, not Franchised

# %%
clust_brand_extras[clust_brand_extras['cluster_id'] == 5]
# Out:
#                              top_genre rating  source  franchise  \
# replace
# Emma (2020)                      Drama     PG  Remake        0.0
# Pete's Dragon                Adventure     PG  Remake        0.0
# Lady and the Tramp               Drama     PG  Remake        0.0
# Dumbo (2019)                 Animation     PG  Remake        0.0
# Annie                           Comedy     PG  Remake        0.0
# Beauty and the Beast             Drama     PG  Remake        0.0
# The Lion King (Live Action)  Animation     PG  Remake        0.0
# Aladdin (2019)                 Fantasy     PG  Remake        0.0
# Cinderella                      Family     PG  Remake        0.0
#
#                              inflated_budget  cluster_id
# replace
# Emma (2020)                        -0.957125           5
# Pete's Dragon                       0.052003           5
# Lady and the Tramp                 -0.082644           5
# Dumbo (2019)                        1.520570           5
# Annie                               0.065947           5
# Beauty and the Beast                1.475075           5
# The Lion King (Live Action)         2.832290           5
# Aladdin (2019)                      1.695466           5
# Cinderella                          0.575664           5

# %% [markdown]
# ## Cluster 6: Original, PG/G

# %%
clust_brand_extras[clust_brand_extras['cluster_id'] == 6].head(15)
# Out:
#                                     top_genre rating    source  franchise  \
# replace
# Finding Dory                        Adventure     PG  Original        1.0
# Zootopia                            Adventure     PG  Original        0.0
# The Good Dinosaur                   Adventure     PG  Original        0.0
# The Resurrection of Gavin Stone       Romance     PG  Original        0.0
# Ralph Breaks the Internet           Adventure     PG  Original        1.0
# Spaceballs                             Comedy     PG  Original        0.0
# Hotel Transylvania 2                   Family     PG  Original        1.0
# Ice Age: Collision Course           Animation     PG  Original        1.0
# Madagascar 3: Europe's Most Wanted     Comedy     PG  Original        1.0
# Madagascar                          Adventure     PG  Original        1.0
# Kung Fu Panda                       Adventure     PG  Original        1.0
# Inside Out                          Animation     PG  Original        0.0
# The Miracle Season                      Drama     PG  Original        0.0
# Penguins of Madagascar              Adventure     PG  Original        1.0
# Beverly Hills Chihuahua                Family     PG  Original        1.0
#
#                                     inflated_budget  cluster_id
# replace
# Finding Dory                               2.147885           6
# Zootopia                                   1.371633           6
# The Good Dinosaur                          1.990546           6
# The Resurrection of Gavin Stone           -0.926722           6
# Ralph Breaks the Internet                  1.639665           6
# Spaceballs                                -0.212720           6
# Hotel Transylvania 2                       0.300548           6
# Ice Age: Collision Course                  0.673005           6
# Madagascar 3: Europe's Most Wanted         1.396108           6
# Madagascar                                 0.473859           6
# Kung Fu Panda                              1.292714           6
# Inside Out                                 1.794035           6
# The Miracle Season                        -0.957125           6
# Penguins of Madagascar                     1.120497           6
# Beverly Hills Chihuahua                   -0.610996           6

# %% [markdown]
# ## Cluster 7: Remake, PG-13

# %%
clust_brand_extras[clust_brand_extras['cluster_id'] == 7]
# Out:
#                                 top_genre rating  source  franchise  \
# replace
# Fantastic Four                     Sci Fi  PG-13  Remake        1.0
# Hellboy (2004)                     Sci Fi  PG-13  Remake        1.0
# The Hustle                         Comedy  PG-13  Remake        0.0
# Murder on the Orient Express      Mystery  PG-13  Remake        0.0
# The Magnificent Seven             Western  PG-13  Remake        0.0
# RoboCop (2014)                     Sci Fi  PG-13  Remake        1.0
# Midnight Sun                        Drama  PG-13  Remake        0.0
# Miss Bala                        Thriller  PG-13  Remake        0.0
# Ghostbusters                       Action  PG-13  Remake        1.0
# Godzilla                         Thriller  PG-13  Remake        1.0
# Godzilla: King of the Monsters  Adventure  PG-13  Remake        1.0
#
#                                 inflated_budget  cluster_id
# replace
# Fantastic Four                         0.929384           7
# Hellboy (2004)                         0.226502           7
# The Hustle                            -0.651057           7
# Murder on the Orient Express          -0.121056           7
# The Magnificent Seven                  0.440130           7
# RoboCop (2014)                         0.931622           7
# Midnight Sun                          -0.915576           7
# Miss Bala                             -0.738505           7
# Ghostbusters                           1.278482           7
# Godzilla                               1.561205           7
# Godzilla: King of the Monsters         1.520570           7

# %% [markdown]
# ## Cluster 8: Remake, R

# %%
clust_brand_extras[clust_brand_extras['cluster_id'] == 8]
# Out:
#                   top_genre rating  source  franchise  inflated_budget  \
# replace
# Blade Runner 2049    Sci Fi      R  Remake        1.0         1.855106
# Hellboy (2019)      Fantasy      R  Remake        0.0        -0.228391
# Pet Sematary         Horror      R  Remake        0.0        -0.651057
# Superfly             Action      R  Remake        0.0        -0.719704
# The Birdcage         Comedy      R  Remake        0.0        -0.220690
# The Beguiled        Western      R  Remake        0.0        -0.805112
# Downhill              Drama      R  Remake        0.0        -0.957125
# Child's Play         Horror      R  Remake        1.0        -0.811378
# It (2017)            Horror      R  Remake        1.0        -0.425081
# Chef                 Comedy      R  Remake        0.0        -0.783990
#
#                    cluster_id
# replace
# Blade Runner 2049           8
# Hellboy (2019)              8
# Pet Sematary                8
# Superfly                    8
# The Birdcage                8
# The Beguiled                8
# Downhill                    8
# Child's Play                8
# It (2017)                   8
# Chef                        8
