# %%
import bs4 as bs
import pandas as pd
import numpy as np
import re
import requests
from random import choice 
from bs4 import SoupStrainer, BeautifulSoup

from urllib.parse import urlencode, urlparse, parse_qs


user_agents = [
    'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.36',
    'Opera/9.80 (X11; Linux i686; Ubuntu/14.10) Presto/2.12.388 Version/12.16',
    'Mozilla/5.0 (Windows; U; Windows NT 6.1; rv:2.2) Gecko/20110201',
    'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.75.14 (KHTML, like Gecko) Version/7.0.3 Safari/7046A194A',
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Safari/537.36 Edge/12.246'
]

# %%
brands = pd.read_csv('../utils/alex_clusters.csv')
all_movies = pd.read_csv('../extras/movie_data.csv')

# %%
all_movies.columns = [re.sub("(b\')|(\')|(\\\\n *)|(\")", "", x) for x in all_movies.columns]

# %%
all_movies['Movie'] = [re.sub("(b\')|(b\")|(\'\")", '', x[:-1]) for x in all_movies['Movie']]
all_movies['DomesticGross'] = [re.sub("(b\')|(b\")|(\'\")|(,)|(\$)", '', x[:-1]) for x in all_movies['DomesticGross']]

# %%
movies = list(all_movies.Movie.values)

# %%
max(all_movies['DomesticGross'].astype(int))
# Out:
# 936662225

# %%
[x for x in brands['replace'].values if x not in movies]
# Out:
# ['Terminator Genisys',
#  "The Huntsman: Winter's War",
#  "The Girl in the Spider's Web: A New Dragon Tattoo Story",
#  'Hellboy (2019)',
#  'Dora and The Lost City of Gold',
#  'Teen Titans Go! to the Movies',
#  "Ocean's 8",
#  'Deliver Us From Evil',
#  "Don't Breathe",
#  "Assassin's Creed Movie",
#  'The Warrior Queen of Jhansi',
#  'Insurgent',
#  'Isle of Dogs',
#  'The LEGO NINJAGO Movie',
#  'Whitney (2018)',
#  'Every Day',
#  'The Circle (2017)',
#  'Ralph Breaks the Internet',
#  'Sisters (2015)',
#  "Where'd You Go, Bernadette?",
#  'Long Shot (2019)',
#  'Heaven Is for Real',
#  'Shaft (2019)',
#  'The Purge (2013)',
#  "A Dog's Journey",
#  'Venom (2018)',
#  "Tyler Perry's Boo 2! A Madea Halloween",
#  'The Old Man & the Gun',
#  'Manchester By the Sea',
#  'Vice (2018)',
#  'The Gift (2015)',
#  'The Hunt (2020)',
#  "Tyler Perry's A Madea Family Funeral",
#  'Life Itself (2018)',
#  'Chappaquiddick',
#  'The Mule (2018)',
#  'This Is The End',
# ...

# %%
all_movies = all_movies.append({'Movie': 'Terminator Genisys', 'DomesticGross': '440600000'}, ignore_index=True)
all_movies = all_movies.append({'Movie': "The Huntsman: Winter's War", 'DomesticGross': '165000000'}, ignore_index=True)
all_movies = all_movies.append({'Movie': "The Girl in the Spider's Web: A New Dragon Tattoo Story", 'DomesticGross': '35200000'}, ignore_index=True)
all_movies = all_movies.append({'Movie': "Hellboy (2019)", 'DomesticGross': '44700000'}, ignore_index=True)
all_movies = all_movies.append({'Movie': "The Girl in the Spider's Web: A New Dragon Tattoo Story", 'DomesticGross': '35200000'}, ignore_index=True)
all_movies = all_movies.append({'Movie': 'Dora and The Lost City of Gold', 'DomesticGross': '120600000'}, ignore_index=True)
all_movies = all_movies.append({'Movie': 'Teen Titans Go! to the Movies', 'DomesticGross': '52100000'}, ignore_index=True)
all_movies = all_movies.append({'Movie': "Ocean's 8", 'DomesticGross': '297000000'}, ignore_index=True)
all_movies = all_movies.append({'Movie': 'Deliver Us From Evil', 'DomesticGross': '87900000'}, ignore_index=True)
all_movies = all_movies.append({'Movie': "Don't Breathe", 'DomesticGross': '157100000'}, ignore_index=True)
all_movies = all_movies.append({'Movie': "Assassin's Creed Movie", 'DomesticGross': '240700000'}, ignore_index=True)
all_movies = all_movies.append({'Movie': 'The Warrior Queen of Jhansi', 'DomesticGross': '174102'}, ignore_index=True)
all_movies = all_movies.append({'Movie': 'Insurgent', 'DomesticGross': '297300000'}, ignore_index=True)
all_movies = all_movies.append({'Movie': 'Isle of Dogs', 'DomesticGross': '64200000'}, ignore_index=True)
all_movies = all_movies.append({'Movie': 'The LEGO NINJAGO Movie', 'DomesticGross': '123100000'}, ignore_index=True)
all_movies = all_movies.append({'Movie': 'Whitney (2018)', 'DomesticGross': '4700000'}, ignore_index=True)
all_movies = all_movies.append({'Movie': 'Every Day', 'DomesticGross': '10400000'}, ignore_index=True)
all_movies = all_movies.append({'Movie': 'The Circle (2017)', 'DomesticGross': '40700000'}, ignore_index=True)
all_movies = all_movies.append({'Movie': 'Ralph Breaks the Internet', 'DomesticGross': '529300000'}, ignore_index=True)
all_movies = all_movies.append({'Movie': 'Sisters (2015)', 'DomesticGross': '105000000'}, ignore_index=True)
all_movies = all_movies.append({'Movie': "Where'd You Go, Bernadette?", 'DomesticGross': '10400000'}, ignore_index=True)
all_movies = all_movies.append({'Movie': 'Long Shot (2019)', 'DomesticGross': '53400000'}, ignore_index=True)
all_movies = all_movies.append({'Movie': 'Heaven Is for Real', 'DomesticGross': '101300000'}, ignore_index=True)
all_movies = all_movies.append({'Movie': 'Shaft (2019)', 'DomesticGross': '21400000'}, ignore_index=True)
all_movies = all_movies.append({'Movie': 'The Purge (2013)', 'DomesticGross': '89300000'}, ignore_index=True)
all_movies = all_movies.append({'Movie': "A Dog's Journey", 'DomesticGross': '75600000'}, ignore_index=True)
all_movies = all_movies.append({'Movie': 'Venom (2018)', 'DomesticGross': '856100000'}, ignore_index=True)
all_movies = all_movies.append({'Movie': "Tyler Perry's Boo 2! A Madea Halloween", 'DomesticGross': '48300000'}, ignore_index=True)
all_movies = all_movies.append({'Movie': 'The Old Man & the Gun', 'DomesticGross': '17900000'}, ignore_index=True)
all_movies = all_movies.append({'Movie': 'Manchester By the Sea', 'DomesticGross': '79000000'}, ignore_index=True)
all_movies = all_movies.append({'Movie': 'Vice (2018)', 'DomesticGross': '76100000'}, ignore_index=True)
all_movies = all_movies.append({'Movie': 'The Gift (2015)', 'DomesticGross': '58900000'}, ignore_index=True)
all_movies = all_movies.append({'Movie': 'The Hunt (2020)', 'DomesticGross': '5812500'}, ignore_index=True)

# %%
movies = list(all_movies.Movie.values)
[x for x in brands['replace'].values if x not in movies]
# Out:
# ["Tyler Perry's A Madea Family Funeral",
#  'Life Itself (2018)',
#  'Chappaquiddick',
#  'The Mule (2018)',
#  'This Is The End',
#  'The Miracle Season',
#  'The Predator (2018)',
#  'Goodbye Christopher Robin',
#  'Pavarotti',
#  'Wendy',
#  'Onward',
#  "A Dog's Way Home",
#  'The Wind Rises',
#  'Active Measures',
#  'Batman v. Superman: Dawn of Justice',
#  'Absolutely Fabulous: The Movie',
#  'Cafe Society',
#  'Boo! A Madea Halloween',
#  'Emma (2020)',
#  'Into The Woods',
#  "A Dog's Purpose",
#  'Island of Lemurs: Madagascar',
#  'The Dark Tower (2017)',
#  'RoboCop (2014)',
#  'Insidious: Chapter 2',
#  'A Hidden Life',
#  'Robin Hood (2018)',
#  'The Jungle Book (2016)',
#  'Criminal (2016)',
#  'One Child Nation',
#  'T2 Trainspotting',
#  'Alpha (2018)',
#  'Spotlight (2015)',
#  "Pete's Dragon",
#  'The Sun Is Also a Star',
#  'Mamma Mia! Here We Go Again',
#  'Parasite (2019)',
#  'Blinded By The Light',
#  'The Way Back (2020)',
#  'Missing Link',
# ...

# %%
all_movies = all_movies.append({'Movie': "Tyler Perry's A Madea Family Funeral", 'DomesticGross': '74800000'}, ignore_index=True)
all_movies = all_movies.append({'Movie': 'Life Itself (2018)', 'DomesticGross': '4102648'}, ignore_index=True)
all_movies = all_movies.append({'Movie': 'Chappaquiddick', 'DomesticGross': '18000000'}, ignore_index=True)
all_movies = all_movies.append({'Movie': 'The Mule (2018)', 'DomesticGross': '174500000'}, ignore_index=True)
all_movies = all_movies.append({'Movie': 'This Is The End', 'DomesticGross': '126500000'}, ignore_index=True)
all_movies = all_movies.append({'Movie': 'The Miracle Season', 'DomesticGross': '10200000'}, ignore_index=True)
all_movies = all_movies.append({'Movie': 'The Predator (2018)', 'DomesticGross': '160500000'}, ignore_index=True)
all_movies = all_movies.append({'Movie': 'Goodbye Christopher Robin', 'DomesticGross': '7200000'}, ignore_index=True)
all_movies = all_movies.append({'Movie': 'Pavarotti', 'DomesticGross': '7200000'}, ignore_index=True)
all_movies = all_movies.append({'Movie': 'Wendy', 'DomesticGross': '143518'}, ignore_index=True)
all_movies = all_movies.append({'Movie': 'Onward', 'DomesticGross': '103200000'}, ignore_index=True)
all_movies = all_movies.append({'Movie': "A Dog's Way Home", 'DomesticGross': '80700000'}, ignore_index=True)
all_movies = all_movies.append({'Movie': 'The Wind Rises', 'DomesticGross': '136500000'}, ignore_index=True)
all_movies = all_movies.append({'Movie': 'Active Measures', 'DomesticGross': '19862'}, ignore_index=True)
all_movies = all_movies.append({'Movie': 'Batman v. Superman: Dawn of Justice', 'DomesticGross': '872700000'}, ignore_index=True)
all_movies = all_movies.append({'Movie': 'Absolutely Fabulous: The Movie', 'DomesticGross': '37900000'}, ignore_index=True)
all_movies = all_movies.append({'Movie': 'Cafe Society', 'DomesticGross': '43800000'}, ignore_index=True)
all_movies = all_movies.append({'Movie': 'Boo! A Madea Halloween', 'DomesticGross': '74800000'}, ignore_index=True)

# %%
movies = list(all_movies.Movie.values)
rem = [x for x in brands['replace'].values if x not in movies]
box_office = []


for x in rem:
    
    text = str(x) + ' box office'
    url = 'https://google.com/search?q=' + text
    page = requests.get(url)
    soup = BeautifulSoup(page.content)

    
    
    #driver.get('https://www.google.com/')
    #search = driver.find_element_by_name('q')
    #search.send_keys(x + ' box office')
    #search.send_keys(Keys.RETURN)
    
    #page = requests.get(driver.current_url)
    #soup = BeautifulSoup(page.content)
    
    try:
        res = str(soup)[str(soup).index('USD')-20:].split('>')[1]
        if 'USD' in res:
            box_office.append((x, res))
        else:
            continue
    except:
        continue

# %%
len(rem)
# Out:
# 98

# %%
box_office
# Out:
# [('Emma (2020)', '25.2\xa0million USD</div'),
#  ('Into The Woods', '213.1\xa0million USD</div'),
#  ("A Dog's Purpose", '205.7\xa0million USD</div'),
#  ('Island of Lemurs: Madagascar', '132\xa0million USD</div'),
#  ('The Dark Tower (2017)', '113.2\xa0million USD</div'),
#  ('RoboCop (2014)', '242.6\xa0million USD</div'),
#  ('Insidious: Chapter 2', '161.9\xa0million USD</div'),
#  ('A Hidden Life', '4.1\xa0million USD</div'),
#  ('Robin Hood (2018)', '85.8\xa0million USD</div'),
#  ('The Jungle Book (2016)', '966.6\xa0million USD</div'),
#  ('Criminal (2016)', '38.8\xa0million USD</div'),
#  ('One Child Nation', '271,841 USD</div'),
#  ('Alpha (2018)', '99.6\xa0million USD</div'),
#  ('Spotlight (2015)', '98.3\xa0million USD</div'),
#  ("Pete's Dragon", '143.7\xa0million USD</div'),
#  ('The Sun Is Also a Star', '6.8\xa0million USD</div'),
#  ('Mamma Mia! Here We Go Again', '615.7\xa0million USD</div'),
#  ('Parasite (2019)', '266\xa0million USD</div'),
# ...

# %%
box_office.append(('T2 Trainspotting', '51012359'))
box_office.append(('The Way Back (2020)', '14700000'))
box_office.append(('The Invisible Man (2020)', '126100000'))
box_office.append(('The Lion King (Live Action)', '543600000'))
box_office.append(('I Still Believe', '10500000'))
box_office.append(('Judy', '43200000'))
box_office.append(('Trolls World Tour', '160800000'))
box_office.append(('Behind the Candelabra', '1310896'))

# %%
box_office_fix = [round(round(float(re.sub('(\\xa0million USD)|(USD)|(\,)|(<\/div)|(<\/span)', '', x)), 4)*1000000) if 'million' in x else round(round(float(re.sub('(\\xa0billion USD)|(USD)|(\,)|(<\/div)|(<\/span)', '', x)), 4)*1000000000) if 'billion' in x else int(float(re.sub('(\,)|(<\/div)|(USD)', '', x)))for x in [x[1] for x in box_office]]

# %%
for x in range(0, len(box_office_fix)):
    print(box_office[x][0], "|", box_office[x][1], "|", box_office_fix[x])
# Out:
# Emma (2020) | 25.2 million USD</div | 25200000
# Into The Woods | 213.1 million USD</div | 213100000
# A Dog's Purpose | 205.7 million USD</div | 205700000
# Island of Lemurs: Madagascar | 132 million USD</div | 132000000
# The Dark Tower (2017) | 113.2 million USD</div | 113200000
# RoboCop (2014) | 242.6 million USD</div | 242600000
# Insidious: Chapter 2 | 161.9 million USD</div | 161900000
# A Hidden Life | 4.1 million USD</div | 4100000
# Robin Hood (2018) | 85.8 million USD</div | 85800000
# The Jungle Book (2016) | 966.6 million USD</div | 966600000
# Criminal (2016) | 38.8 million USD</div | 38800000
# One Child Nation | 271,841 USD</div | 271841
# Alpha (2018) | 99.6 million USD</div | 99600000
# Spotlight (2015) | 98.3 million USD</div | 98300000
# Pete's Dragon | 143.7 million USD</div | 143700000
# The Sun Is Also a Star | 6.8 million USD</div | 6800000
# Mamma Mia! Here We Go Again | 615.7 million USD</div | 615700000
# Parasite (2019) | 266 million USD</div | 266000000
# ...

# %%
max(box_office_fix)
# Out:
# 2066000000

# %%
for x in range(len(box_office)):
    all_movies = all_movies.append({'Movie': box_office[x][0], 'DomesticGross': box_office_fix[x]}, ignore_index=True)

# %%
all_movies.to_csv('../data/movie_data_w_bo_fixed.csv')

# %%
test = pd.merge(brands, all_movies, left_on='replace', right_on='Movie')

# %%
test.drop_duplicates('replace')
# Out:
#      Unnamed: 0  brand_ods_id                 replace released_on  \
# 0             0         41301       Blade Runner 2049  2017-10-06
# 1             1         25859                Geostorm  2017-10-20
# 2             2         44895        Ready Player One  2018-03-29
# 3             3         10617                    Fury  2014-10-17
# 4             4         10607            Nightcrawler  2014-10-31
# ..          ...           ...                     ...         ...
# 531         521         10654              Cinderella  2015-03-13
# 533         522         12271                    Chef  2014-05-30
# 534         523         41315  A Street Cat Named Bob  2016-11-18
# 535         524         60789   Behind the Candelabra  2013-01-26
# 536         525         60626                  Looper  2012-09-28
#
#     ticker_symbol                           genres  \
# 0               T                           Sci Fi
# 1               T                   Action, Sci Fi
# ...
